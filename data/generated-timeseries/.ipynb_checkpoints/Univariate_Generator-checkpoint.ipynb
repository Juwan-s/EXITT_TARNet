# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import collections 
import time
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import TensorDataset, DataLoader

# %%
np.random.seed(42)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:0'

# %%
train = pd.read_csv('./SmartFall Training.csv')
test = pd.read_csv('./SmartFall Testing.csv')

# %%
n = 120
X_train_adl, X_train_fall, y_train_adl, y_train_fall = list(), list(), list(), list()

for i in tqdm(range(0, len(train)-n)):
    temp = list()
    
    temp.append(train[' ms_accelerometer_x'][i : i + n])
    temp.append(train[' ms_accelerometer_y'][i : i + n])
    temp.append(train[' ms_accelerometer_z'][i : i + n])
    
    cnt = collections.Counter(train['outcome'][i: i + n])
    num_adl = cnt[0]
    num_fall = cnt[1]
    
    if num_fall == 25:
        y_train_fall.append(1)
        X_train_fall.append(temp)
                    
    elif num_fall == 0:
        y_train_adl.append(0)
        X_train_adl.append(temp)
    else:
        continue
# Out:
# 100%|██████████| 92661/92661 [00:29<00:00, 3130.72it/s]

# %%
X_test_adl, X_test_fall, y_test_adl, y_test_fall, fall_range = list(), list(), list(), list(), list()
for i in tqdm(range(0, len(test) - n)):
    temp = list()
    
    temp.append(test[' ms_accelerometer_x'][i : i + n])
    temp.append(test[' ms_accelerometer_y'][i : i + n])
    temp.append(test[' ms_accelerometer_z'][i : i + n])
    
    cnt = collections.Counter(test['outcome'][i : i + n])
    num_adl = cnt[0]
    num_fall = cnt[1]
    
    if num_fall == 25:
        y_test_fall.append(1)
        X_test_fall.append(temp)
                
        fall_range.append(test['outcome'][i : i + n])
        
    elif num_fall == 0:
        y_test_adl.append(0)
        X_test_adl.append(temp)
    else:
        continue
# Out:
# 100%|██████████| 90905/90905 [00:30<00:00, 2973.74it/s]

# %%
index = 17

# %%
import numpy as np
import matplotlib.pyplot as plt

# fall_range[index]에서 값이 1인 부분의 시작과 끝 인덱스 찾기
ones = np.where(fall_range[index] == 1)[0]
start_indices = np.where(np.diff(ones) != 1)[0] + 1
start_indices = np.insert(start_indices, 0, 0)
end_indices = np.where(np.diff(ones) != 1)[0]
end_indices = np.append(end_indices, len(ones) - 1)
plt.figure(figsize=(16, 4))
# Plot
x = np.array(X_test_fall[index]).transpose(1, 0)
plt.plot(x)

y1 = min(np.min(x), 0)
y2 = max(np.max(x), 1)

# 각 값이 1인 부분에 대해 빨간색 배경 추가
for start, end in zip(start_indices, end_indices):
    plt.fill_betweenx([y1, y2], ones[start], ones[end], color='red', alpha=0.3)

plt.ylim(y1, y2)
plt.show()

# %%
print(len(y_test_fall))
print(len(y_test_adl))
# Out:
# 19204
# 19204

# %%
print(len(y_train_fall))
print(len(y_train_adl))
# Out:
# 30890
# 30890

# %%
X_train_adl = X_train_adl[:10000]
y_train_adl = y_train_adl[:10000]

y_train = y_train_adl + y_train_fall[:10000]
X_train = X_train_adl + X_train_fall[:10000]

# %%
X_test_adl = X_test_adl[:10000]
y_test_adl = y_test_adl[:10000]

y_test = y_test_adl + y_test_fall[:10000]
X_test = X_test_adl + X_test_fall[:10000]

# %%
print(len(y_test_fall))
print(len(y_test_adl))
# Out:
# 19204
# 10000

# %%
print('length of test data', len(X_test))
# Out:
# length of test data 20000

# %%
print('train data adl and fall ratio')
print('--------------------------------')
cnt_train = collections.Counter(y_train)
print('train data adl ratio: ', cnt_train[0])
print('train data fall ratio: ', cnt_train[1])
print('--------------------------------')

cnt_test = collections.Counter(y_test)
print('test data adl ratio: ', cnt_test[0])
print('test data fall ratio: ', cnt_test[1])
# Out:
# train data adl and fall ratio
# --------------------------------
# train data adl ratio:  10000
# train data fall ratio:  10000
# --------------------------------
# test data adl ratio:  10000
# test data fall ratio:  10000

# %%
 np.asarray(X_train).transpose(0, 2, 1).shape
# Out:
# (20000, 120, 3)

# %%
X_train = np.asarray(X_train).transpose(0, 2, 1)
y_train = np.asarray(y_train).reshape(-1, )

X_test = np.asarray(X_test).transpose(0, 2, 1)
y_test = np.asarray(y_test).reshape(-1, )

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

y_train = enc.fit_transform(y_train)
y_test = enc.fit_transform(y_test)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((20000, 120, 3), (20000,), (20000, 120, 3), (20000,))

# %%
fall_segment = np.asarray(fall_range)[:10000]

# %%
fall_segment.shape
# Out:
# (10000, 120)

# %%
np.where(y_train == 1)
# Out:
# (array([10000, 10001, 10002, ..., 19997, 19998, 19999]),)

# %%
import numpy as np
import matplotlib.pyplot as plt

# fall_range[index]에서 값이 1인 부분의 시작과 끝 인덱스 찾기
ones = np.where(fall_segment[-1000] == 1)[0]
start_indices = np.where(np.diff(ones) != 1)[0] + 1
start_indices = np.insert(start_indices, 0, 0)
end_indices = np.where(np.diff(ones) != 1)[0]
end_indices = np.append(end_indices, len(ones) - 1)
plt.figure(figsize=(16, 4))
# Plot
x = np.array(X_test[-1000])
plt.plot(x)

y1 = min(np.min(x), 0)
y2 = max(np.max(x), 1)

# 각 값이 1인 부분에 대해 빨간색 배경 추가
for start, end in zip(start_indices, end_indices):
    plt.fill_betweenx([y1, y2], ones[start], ones[end], color='red', alpha=0.3)

plt.ylim(y1, y2)
plt.show()

# %%
np.save('./fall_train.npy', X_train)
np.save('./fall_train_label.npy', y_train)
np.save('./fall_test.npy', X_test)
np.save('./fall_test_label.npy', y_test)
np.save('./fall_range.npy', fall_segment)

# %% [markdown]
# # 데이터 시각화 샘플

# %%
test = np.load('./fall_test.npy')

# %%
fall = np.load('./fall_range.npy')

# %%
ones = np.where(fall[0] == 1)[0]

# %%
start_indices = np.where(np.diff(ones) != 1)[0] + 1
start_indices = np.insert(start_indices, 0, 0)
end_indices = np.where(np.diff(ones) != 1)[0]
end_indices = np.append(end_indices, len(ones) - 1)

# %%
y1 = min(np.min(test[10000]), 0)
y2 = max(np.max(test[10000]), 1)

# %%
fig, axs = plt.subplots(2, 1, figsize=(12, ))
plt.subplots_adjust(hspace=0.35)

# 각 plot에 라벨 설정
line1, = axs[0].plot(test[0], label='Daily Activities')
axs[0].tick_params(axis='both', labelsize=16)
axs[0].set_title('Activities of Daily Living Signal', fontsize=18)

line2, = axs[1].plot(test[10000], label='Fall Signal')
axs[1].tick_params(axis='both', labelsize=16)
axs[1].set_title('Fall Signal', fontsize=18)
axs[1].fill_betweenx([y1, y2], ones[0], ones[-1], color='red', alpha=0.3)

# 통합 범례 추가
fig.legend(handles=[line1, line2], loc='upper right', fontsize=18)

fig.text(0.5, 0, 'Time', ha='center', fontsize=18)
fig.text(0.07, 0.5, 'Value', va='center', rotation='vertical', fontsize=18)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fig, axs = plt.subplots(2, 1, figsize=(12, ))
#       2 plt.subplots_adjust(hspace=0.35)
#       4 # 각 plot에 라벨 설정
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/pyplot.py:1501, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1355 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1356              width_ratios=None, height_ratios=None,
#    1357              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1358     """
#    1359     Create a figure and a set of subplots.
#    1360
#    (...)
#    1499
#    1500     """
# -> 1501     fig = figure(**fig_kw)
#    1502     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1503                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1504                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1505                        width_ratios=width_ratios)
#    1506     return fig, axs
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/pyplot.py:840, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     830 if len(allnums) == max_open_warning >= 1:
#     831     _api.warn_external(
#     832         f"More than {max_open_warning} figures have been opened. "
#     833         f"Figures created through the pyplot interface "
#    (...)
#     837         f"Consider using `matplotlib.pyplot.close()`.",
#     838         RuntimeWarning)
# --> 840 manager = new_figure_manager(
#     841     num, figsize=figsize, dpi=dpi,
#     842     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     843     FigureClass=FigureClass, **kwargs)
#     844 fig = manager.canvas.figure
#     845 if fig_label:
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/pyplot.py:384, in new_figure_manager(*args, **kwargs)
#     382 """Create a new figure manager instance."""
#     383 _warn_if_gui_out_of_main_thread()
# --> 384 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/conda/envs/XAI/lib/python3.8/site-packages/matplotlib/figure.py:2536, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2533 if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
#    2534     raise ValueError('figure size must be positive finite not '
#    2535                      f'{figsize}')
# -> 2536 self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#    2538 self.dpi_scale_trans = Affine2D().scale(dpi)
#    2539 # do not use property as it will trigger
#
# TypeError: from_bounds() missing 1 required positional argument: 'height'

# %%
fig, axs = plt.subplots(2, 1, figsize=(12, 6))
plt.subplots_adjust(hspace=0.35)

axs[0].plot(test[0])
axs[0].tick_params(axis='both', labelsize=16)
axs[0].set_title('Activities of Daily Living Signal', fontsize=18)


axs[1].plot(test[10000][:, 0], label = 'acc_x')
axs[1].plot(test[10000][:, 1], label = 'acc_y')
axs[1].plot(test[10000][:, 2], label = 'acc_z')
axs[1].legend(fontsize=14)
axs[1].tick_params(axis='both', labelsize=16)
axs[1].set_title('Fall Signal', fontsize=18)
axs[1].fill_betweenx([y1, y2], ones[0], ones[-1], color='red', alpha=0.3)
fig.text(0.5, 0, 'Time', ha='center', fontsize=18)
fig.text(0.07, 0.5, 'Value', va='center', rotation='vertical', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(test[4])
plt.title('Activities of Daily Living Signal')
plt.subplot(2, 1, 2)
plt.plot(test[10000])

plt.subplots_adjust(hspace=0.3)  # hspace 값을 조절하여 상하 간격을 변경하세요.
plt.title('Fall Signal')
plt.show()
